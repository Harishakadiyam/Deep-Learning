# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import csv

# %%
paragraph = "Recurrent Neural Networks (RNNs) are widely used for next word prediction because they can remember patterns and dependencies in sequences of words. In this task, the model learns the relationship between words by processing text data one word at a time and using its hidden state to retain context. During training, the RNN is given a sequence of words and learns to predict the next word by adjusting its weights over multiple epochs. Once trained, the model can generate text by predicting one word at a time based on the previous words, making it useful for applications like autocomplete, chatbots, and text generation."

# %%
with open('rnn_next_word_prediction.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Description'])
    writer.writerow([paragraph])

# %%
df = pd.read_csv('rnn_next_word_prediction.csv')

print(df.head())
# Out:
#                                          Description
# 0  Recurrent Neural Networks (RNNs) are widely us...

# %%
# Tokenization
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(df['Description'])
seq = tokenizer.texts_to_sequences(df['Description'])

# %%
seq[:10]
# Out:
# [[20,
#   21,
#   22,
#   23,
#   24,
#   25,
#   26,
#   8,
#   9,
#   2,
#   27,
#   28,
#   29,
#   10,
#   30,
#   31,
#   3,
#   32,
#   11,
#   33,
#   12,
#   4,
#   11,
#   34,
#   35,
#   1,
#   13,
#   14,
#   1,
#   36,
#   37,
#   4,
#   5,
#   38,
#   6,
#   39,
#   15,
#   2,
#   16,
#   7,
#   17,
#   3,
#   40,
#   18,
#   41,
#   42,
#   19,
#   43,
#   44,
#   45,
#   46,
#   1,
#   47,
#   48,
#   49,
#   7,
#   50,
#   12,
#   4,
#   3,
#   14,
#   19,
#   51,
#   1,
#   9,
#   2,
#   5,
#   52,
#   18,
#   53,
#   54,
#   55,
#   56,
#   57,
#   58,
#   1,
#   13,
#   10,
#   59,
#   6,
#   5,
#   60,
#   15,
#   2,
#   16,
#   7,
#   17,
#   61,
#   62,
#   1,
#   63,
#   4,
#   64,
#   65,
#   66,
#   8,
#   67,
#   68,
#   69,
#   70,
#   3,
#   6,
#   71]]

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'word': 2,
#  'and': 3,
#  'words': 4,
#  'by': 5,
#  'text': 6,
#  'a': 7,
#  'for': 8,
#  'next': 9,
#  'can': 10,
#  'in': 11,
#  'of': 12,
#  'model': 13,
#  'learns': 14,
#  'one': 15,
#  'at': 16,
#  'time': 17,
#  'its': 18,
#  'to': 19,
#  'recurrent': 20,
#  'neural': 21,
#  'networks': 22,
#  'rnns': 23,
#  'are': 24,
#  'widely': 25,
#  'used': 26,
#  'prediction': 27,
#  'because': 28,
#  'they': 29,
#  'remember': 30,
#  'patterns': 31,
#  'dependencies': 32,
#  'sequences': 33,
#  'this': 34,
#  'task': 35,
#  'relationship': 36,
#  'between': 37,
#  'processing': 38,
#  'data': 39,
#  'using': 40,
#  'hidden': 41,
#  'state': 42,
#  'retain': 43,
#  'context': 44,
#  'during': 45,
#  'training': 46,
#  'rnn': 47,
#  'is': 48,
#  'given': 49,
#  'sequence': 50,
#  'predict': 51,
#  'adjusting': 52,
#  'weights': 53,
#  'over': 54,
#  'multiple': 55,
#  'epochs': 56,
#  'once': 57,
#  'trained': 58,
#  'generate': 59,
#  'predicting': 60,
#  'based': 61,
#  'on': 62,
#  'previous': 63,
#  'making': 64,
#  'it': 65,
#  'useful': 66,
#  'applications': 67,
#  'like': 68,
#  'autocomplete': 69,
#  'chatbots': 70,
#  'generation': 71}

# %%
X = []
y = []
total_words_dropped = 0

for i in seq:
    if len(i) > 1:
        for index in range(1, len(i)):
            X.append(i[:index])
            y.append(i[index])
    else:
        total_words_dropped += 1

print("Total Single Words Dropped are:", total_words_dropped)
# Out:
# Total Single Words Dropped are: 0

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X)
y = tf.keras.utils.to_categorical(y)

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 72

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, 14),
    tf.keras.layers.LSTM(100, return_sequences=True),
    tf.keras.layers.LSTM(100),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(vocab_size,activation='softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# %%
model.fit(X, y, epochs=250)
# Out:
# Epoch 1/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0686 - loss: 4.2206
# Epoch 2/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0588 - loss: 4.1398
# Epoch 3/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0490 - loss: 4.1333
# Epoch 4/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0686 - loss: 4.0764
# Epoch 5/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0686 - loss: 4.0242
# Epoch 6/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0686 - loss: 3.9906
# Epoch 7/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0784 - loss: 3.9513
# Epoch 8/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.0784 - loss: 3.9060
# Epoch 9/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0686 - loss: 3.8643
# Epoch 10/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0686 - loss: 3.8274
# Epoch 11/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0686 - loss: 3.7910
# Epoch 12/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0784 - loss: 3.7600
# Epoch 13/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0686 - loss: 3.7236
# Epoch 14/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0980 - loss: 3.6906
# Epoch 15/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0980 - loss: 3.6626
# Epoch 16/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0882 - loss: 3.6293
# Epoch 17/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0882 - loss: 3.6111
# Epoch 18/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0686 - loss: 3.6151
# Epoch 19/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0882 - loss: 3.6346
# Epoch 20/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0686 - loss: 3.5778
# Epoch 21/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0980 - loss: 3.5186
# Epoch 22/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0980 - loss: 3.4867
# Epoch 23/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0784 - loss: 3.4758
# Epoch 24/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1078 - loss: 3.4456
# Epoch 25/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0882 - loss: 3.4247
# Epoch 26/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0980 - loss: 3.3958
# Epoch 27/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0882 - loss: 3.3901
# Epoch 28/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0882 - loss: 3.3781
# Epoch 29/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.0980 - loss: 3.3608
# Epoch 30/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0784 - loss: 3.3579
# Epoch 31/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1176 - loss: 3.3292
# Epoch 32/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0980 - loss: 3.2773
# Epoch 33/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1078 - loss: 3.2587
# Epoch 34/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1176 - loss: 3.2354
# Epoch 35/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1275 - loss: 3.2225
# Epoch 36/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1275 - loss: 3.2099
# Epoch 37/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1078 - loss: 3.3053
# Epoch 38/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0980 - loss: 3.2822
# Epoch 39/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1078 - loss: 3.2184
# Epoch 40/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1176 - loss: 3.1569
# Epoch 41/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1373 - loss: 3.1276
# Epoch 42/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1471 - loss: 3.0862
# Epoch 43/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1078 - loss: 3.0825
# Epoch 44/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1471 - loss: 3.0200
# Epoch 45/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1471 - loss: 2.9906
# Epoch 46/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1765 - loss: 2.9599
# Epoch 47/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1667 - loss: 2.9315
# Epoch 48/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1471 - loss: 2.9076
# Epoch 49/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1667 - loss: 2.8443
# Epoch 50/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1863 - loss: 2.7890
# Epoch 51/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1863 - loss: 2.7569
# Epoch 52/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1667 - loss: 2.7339
# Epoch 53/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1765 - loss: 2.6660
# Epoch 54/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.
h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\Admin\AVScode\AI\RNN

# %%
vocab_array = np.array(list(tokenizer.word_index.keys()))

vocab_array
# Out:
# array(['the', 'word', 'and', 'words', 'by', 'text', 'a', 'for', 'next',
#        'can', 'in', 'of', 'model', 'learns', 'one', 'at', 'time', 'its',
#        'to', 'recurrent', 'neural', 'networks', 'rnns', 'are', 'widely',
#        'used', 'prediction', 'because', 'they', 'remember', 'patterns',
#        'dependencies', 'sequences', 'this', 'task', 'relationship',
#        'between', 'processing', 'data', 'using', 'hidden', 'state',
#        'retain', 'context', 'during', 'training', 'rnn', 'is', 'given',
#        'sequence', 'predict', 'adjusting', 'weights', 'over', 'multiple',
#        'epochs', 'once', 'trained', 'generate', 'predicting', 'based',
#        'on', 'previous', 'making', 'it', 'useful', 'applications', 'like',
#        'autocomplete', 'chatbots', 'generation'], dtype='<U12')

# %%
def make_prediction(text, n_words):
    for i in range(n_words):
        text_tokenize = tokenizer.texts_to_sequences([text])
        text_padded = tf.keras.preprocessing.sequence.pad_sequences(text_tokenize, maxlen=14)
        prediction = np.squeeze(np.argmax(model.predict(text_padded), axis=-1))
        prediction = str(vocab_array[prediction - 1])
        print(vocab_array[np.argsort(model.predict(text_padded)) - 1].ravel()[:-3])
        text += " " + prediction
    return text

# %%
make_prediction("recurrent", 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'retain' 'generation'
#  'useful' 'once' 'model' 'during' 'previous' 'state' 'and' 'because'
#  'multiple' 'prediction' 'chatbots' 'data' 'weights' 'recurrent' 'this'
#  'to' 'generation' 'using' 'predict' 'training' 'relationship' 'in'
#  'adjusting' 'is' 'autocomplete' 'over' 'patterns' 'predicting'
#  'applications' 'a' 'sequences' 'processing' 'of' 'based' 'between' 'rnn'
#  'its' 'it' 'at' 'generate' 'time' 'making' 'given' 'text' 'like'
#  'trained' 'the' 'on' 'they' 'one' 'hidden' 'remember' 'words' 'context'
#  'epochs' 'can' 'word' 'next' 'for' 'used' 'widely' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'retain' 'once'
#  'generation' 'useful' 'model' 'previous' 'during' 'and' 'state'
#  'chatbots' 'multiple' 'weights' 'recurrent' 'because' 'data' 'this'
#  'relationship' 'prediction' 'generation' 'to' 'using' 'predict'
#  'training' 'in' 'adjusting' 'autocomplete' 'is' 'applications' 'over'
#  'sequences' 'patterns' 'between' 'predicting' 'of' 'processing' 'a'
#  'based' 'making' 'rnn' 'it' 'the' 'text' 'at' 'generate' 'its' 'given'
#  'on' 'time' 'like' 'trained' 'one' 'words' 'hidden' 'they' 'remember'
#  'context' 'epochs' 'can' 'word' 'next' 'for' 'used' 'widely' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'model' 'previous' 'once'
#  'retain' 'useful' 'generation' 'and' 'chatbots' 'relationship' 'during'
#  'state' 'this' 'weights' 'recurrent' 'data' 'multiple' 'sequences'
#  'generation' 'in' 'training' 'using' 'between' 'the' 'because'
#  'autocomplete' 'applications' 'of' 'to' 'predict' 'processing'
#  'adjusting' 'making' 'text' 'over' 'patterns' 'prediction' 'is' 'a'
#  'predicting' 'based' 'generate' 'it' 'on' 'at' 'words' 'given' 'rnn'
#  'time' 'like' 'its' 'trained' 'one' 'hidden' 'context' 'epochs' 'they'
#  'remember' 'can' 'word' 'next' 'for' 'used' 'widely' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ['learns' 'dependencies' 'by' 'task' 'model' 'previous' 'sequence'
#  'relationship' 'chatbots' 'once' 'and' 'sequences' 'this' 'the' 'retain'
#  'training' 'useful' 'generation' 'between' 'weights' 'in' 'during'
#  'state' 'generation' 'recurrent' 'making' 'using' 'of' 'data'
#  'autocomplete' 'words' 'applications' 'multiple' 'text' 'processing' 'to'
#  'on' 'based' 'adjusting' 'generate' 'a' 'over' 'predict' 'it'
#  'predicting' 'is' 'given' 'patterns' 'because' 'rnn' 'at' 'one' 'time'
#  'context' 'trained' 'like' 'its' 'hidden' 'prediction' 'epochs' 'they'
#  'remember' 'can' 'word' 'next' 'for' 'used' 'neural' 'widely']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ['model' 'by' 'previous' 'dependencies' 'learns' 'task' 'relationship'
#  'sequence' 'once' 'sequences' 'chatbots' 'training' 'the' 'and' 'making'
#  'this' 'between' 'words' 'weights' 'of' 'in' 'using' 'autocomplete'
#  'text' 'generation' 'applications' 'recurrent' 'multiple' 'generation'
#  'state' 'retain' 'on' 'useful' 'data' 'processing' 'generate' 'during'
#  'context' 'predicting' 'based' 'trained' 'to' 'over' 'one' 'adjusting'
#  'it' 'a' 'rnn' 'predict' 'given' 'at' 'time' 'epochs' 'is' 'its'
#  'patterns' 'hidden' 'like' 'because' 'prediction' 'they' 'remember' 'can'
#  'word' 'neural' 'next' 'networks' 'for' 'rnns']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['model' 'by' 'previous' 'dependencies' 'relationship' 'learns' 'once'
#  'sequences' 'task' 'training' 'sequence' 'the' 'chatbots' 'of' 'making'
#  'weights' 'and' 'trained' 'predicting' 'generate' 'between' 'text' 'this'
#  'words' 'multiple' 'in' 'autocomplete' 'context' 'over' 'on' 'epochs'
#  'using' 'one' 'recurrent' 'applications' 'to' 'state' 'processing'
#  'based' 'adjusting' 'generation' 'generation' 'data' 'it' 'during' 'its'
#  'a' 'at' 'rnn' 'useful' 'retain' 'given' 'predict' 'time' 'hidden'
#  'patterns' 'like' 'is' 'remember' 'because' 'they' 'can' 'prediction'
#  'neural' 'networks' 'word' 'rnns' 'next' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['model' 'sequences' 'by' 'once' 'relationship' 'dependencies' 'previous'
#  'learns' 'training' 'of' 'task' 'the' 'generate' 'sequence' 'predicting'
#  'trained' 'weights' 'over' 'epochs' 'making' 'multiple' 'chatbots' 'text'
#  'on' 'one' 'between' 'context' 'this' 'autocomplete' 'in' 'words' 'and'
#  'to' 'applications' 'using' 'recurrent' 'based' 'adjusting' 'its' 'it'
#  'processing' 'state' 'generation' 'data' 'a' 'generation' 'at' 'during'
#  'rnn' 'given' 'hidden' 'time' 'predict' 'useful' 'retain' 'like'
#  'patterns' 'is' 'neural' 'remember' 'can' 'they' 'because' 'networks'
#  'rnns' 'prediction' 'are' 'widely' 'word']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['model' 'sequences' 'relationship' 'once' 'by' 'of' 'generate' 'over'
#  'dependencies' 'previous' 'predicting' 'epochs' 'weights' 'training'
#  'trained' 'learns' 'task' 'the' 'sequence' 'on' 'one' 'multiple' 'making'
#  'text' 'context' 'autocomplete' 'applications' 'between' 'this' 'to'
#  'chatbots' 'words' 'in' 'based' 'its' 'using' 'recurrent' 'and' 'it' 'at'
#  'a' 'adjusting' 'processing' 'state' 'given' 'data' 'like' 'generation'
#  'generation' 'time' 'hidden' 'during' 'rnn' 'neural' 'predict' 'retain'
#  'useful' 'is' 'patterns' 'rnns' 'networks' 'remember' 'can' 'are' 'they'
#  'widely' 'because' 'used' 'prediction']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['model' 'sequences' 'relationship' 'over' 'once' 'generate' 'epochs'
#  'weights' 'predicting' 'of' 'on' 'one' 'training' 'previous' 'multiple'
#  'trained' 'by' 'making' 'applications' 'sequence' 'learns' 'the'
#  'context' 'task' 'autocomplete' 'based' 'text' 'dependencies' 'between'
#  'to' 'using' 'at' 'this' 'its' 'a' 'given' 'like' 'chatbots' 'words' 'it'
#  'time' 'hidden' 'in' 'recurrent' 'neural' 'adjusting' 'state' 'predict'
#  'processing' 'during' 'rnn' 'generation' 'data' 'generation' 'is'
#  'retain' 'useful' 'and' 'rnns' 'networks' 'patterns' 'are' 'widely'
#  'remember' 'used' 'can' 'for' 'they' 'next']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['over' 'generate' 'on' 'epochs' 'weights' 'once' 'relationship'
#  'multiple' 'predicting' 'one' 'training' 'based' 'model' 'previous'
#  'making' 'trained' 'applications' 'sequences' 'context' 'by' 'of'
#  'autocomplete' 'given' 'between' 'sequence' 'to' 'text' 'the' 'a' 'at'
#  'learns' 'it' 'like' 'time' 'task' 'using' 'hidden' 'predict' 'chatbots'
#  'neural' 'its' 'rnn' 'during' 'recurrent' 'is' 'adjusting' 'words' 'this'
#  'state' 'rnns' 'dependencies' 'generation' 'processing' 'retain'
#  'generation' 'useful' 'data' 'in' 'networks' 'are' 'and' 'widely'
#  'patterns' 'used' 'for' 'remember' 'next' 'can' 'word']
# 'recurrent neural networks networks are widely used for word word because'

# %%
make_prediction("neural", 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'retain' 'generation'
#  'useful' 'once' 'model' 'during' 'previous' 'state' 'and' 'because'
#  'multiple' 'prediction' 'chatbots' 'data' 'weights' 'recurrent' 'this'
#  'to' 'generation' 'using' 'predict' 'relationship' 'training' 'in'
#  'adjusting' 'autocomplete' 'is' 'over' 'patterns' 'predicting'
#  'applications' 'a' 'sequences' 'processing' 'of' 'based' 'between' 'rnn'
#  'it' 'its' 'at' 'generate' 'time' 'making' 'given' 'text' 'like' 'the'
#  'trained' 'on' 'they' 'one' 'hidden' 'remember' 'words' 'context'
#  'epochs' 'can' 'word' 'next' 'for' 'used' 'widely' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'retain' 'once'
#  'generation' 'model' 'useful' 'previous' 'during' 'and' 'state'
#  'chatbots' 'weights' 'multiple' 'recurrent' 'because' 'data'
#  'relationship' 'this' 'prediction' 'generation' 'to' 'using' 'predict'
#  'training' 'in' 'autocomplete' 'adjusting' 'sequences' 'is'
#  'applications' 'over' 'between' 'patterns' 'of' 'predicting' 'processing'
#  'a' 'based' 'the' 'making' 'text' 'it' 'rnn' 'at' 'generate' 'its'
#  'given' 'on' 'time' 'like' 'trained' 'one' 'words' 'hidden' 'they'
#  'remember' 'context' 'epochs' 'can' 'word' 'next' 'for' 'used' 'widely'
#  'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ['learns' 'dependencies' 'by' 'task' 'sequence' 'model' 'previous' 'once'
#  'retain' 'useful' 'generation' 'and' 'relationship' 'chatbots' 'during'
#  'state' 'this' 'weights' 'recurrent' 'sequences' 'data' 'multiple' 'in'
#  'generation' 'training' 'between' 'using' 'the' 'of' 'autocomplete'
#  'applications' 'because' 'to' 'predict' 'making' 'text' 'processing'
#  'adjusting' 'over' 'patterns' 'a' 'is' 'predicting' 'based' 'prediction'
#  'generate' 'on' 'it' 'words' 'at' 'given' 'rnn' 'time' 'like' 'its'
#  'trained' 'one' 'hidden' 'context' 'epochs' 'they' 'remember' 'can'
#  'word' 'next' 'for' 'used' 'widely' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ['learns' 'dependencies' 'by' 'model' 'previous' 'task' 'sequence'
#  'relationship' 'chatbots' 'once' 'and' 'sequences' 'the' 'training'
#  'this' 'retain' 'useful' 'generation' 'between' 'weights' 'in' 'making'
#  'generation' 'during' 'state' 'using' 'recurrent' 'of' 'words' 'data'
#  'autocomplete' 'applications' 'text' 'multiple' 'processing' 'on' 'to'
#  'based' 'adjusting' 'generate' 'a' 'over' 'predict' 'it' 'predicting'
#  'given' 'is' 'rnn' 'one' 'at' 'context' 'patterns' 'because' 'time'
#  'trained' 'like' 'its' 'hidden' 'prediction' 'epochs' 'they' 'remember'
#  'can' 'word' 'next' 'for' 'used' 'neural' 'networks']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['model' 'by' 'previous' 'dependencies' 'learns' 'task' 'relationship'
#  'sequence' 'once' 'sequences' 'chatbots' 'training' 'the' 'and' 'making'
#  'this' 'between' 'words' 'weights' 'of' 'in' 'using' 'autocomplete'
#  'text' 'generation' 'applications' 'recurrent' 'multiple' 'state'
#  'generation' 'on' 'generate' 'retain' 'context' 'processing' 'data'
#  'useful' 'during' 'predicting' 'trained' 'based' 'over' 'to' 'one'
#  'adjusting' 'it' 'a' 'rnn' 'epochs' 'given' 'predict' 'at' 'time' 'its'
#  'is' 'hidden' 'patterns' 'like' 'because' 'prediction' 'remember' 'they'
#  'can' 'word' 'neural' 'next' 'networks' 'for' 'rnns']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ['model' 'by' 'previous' 'dependencies' 'once' 'relationship' 'learns'
#  'sequences' 'task' 'training' 'sequence' 'the' 'chatbots' 'of' 'making'
#  'weights' 'trained' 'and' 'predicting' 'generate' 'between' 'text'
#  'multiple' 'this' 'words' 'over' 'epochs' 'in' 'autocomplete' 'context'
#  'on' 'using' 'one' 'recurrent' 'applications' 'to' 'state' 'processing'
#  'based' 'adjusting' 'generation' 'generation' 'data' 'it' 'during' 'its'
#  'a' 'at' 'rnn' 'useful' 'retain' 'given' 'predict' 'time' 'hidden'
#  'patterns' 'like' 'is' 'remember' 'because' 'they' 'can' 'prediction'
#  'neural' 'networks' 'rnns' 'word' 'next' 'are']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ['model' 'sequences' 'by' 'once' 'relationship' 'dependencies' 'previous'
#  'learns' 'training' 'of' 'task' 'the' 'generate' 'predicting' 'trained'
#  'sequence' 'weights' 'over' 'epochs' 'making' 'multiple' 'text'
#  'chatbots' 'on' 'one' 'context' 'between' 'autocomplete' 'this' 'in'
#  'words' 'and' 'to' 'applications' 'using' 'recurrent' 'based' 'its'
#  'adjusting' 'it' 'processing' 'state' 'generation' 'data' 'a' 'at'
#  'generation' 'during' 'given' 'rnn' 'hidden' 'time' 'predict' 'useful'
#  'like' 'retain' 'is' 'patterns' 'neural' 'remember' 'can' 'they'
#  'networks' 'because' 'rnns' 'prediction' 'are' 'widely' 'word']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# ['model' 'sequences' 'relationship' 'once' 'by' 'of' 'generate' 'over'
#  'previous' 'dependencies' 'predicting' 'epochs' 'weights' 'training'
#  'trained' 'learns' 'task' 'the' 'sequence' 'on' 'one' 'multiple' 'making'
#  'text' 'context' 'autocomplete' 'applications' 'between' 'this' 'to'
#  'chatbots' 'words' 'in' 'based' 'its' 'using' 'recurrent' 'it' 'at' 'and'
#  'a' 'adjusting' 'processing' 'state' 'given' 'like' 'data' 'generation'
#  'time' 'hidden' 'generation' 'during' 'neural' 'rnn' 'predict' 'retain'
#  'useful' 'is' 'patterns' 'rnns' 'networks' 'remember' 'are' 'can'
#  'widely' 'they' 'because' 'used' 'prediction']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['model' 'sequences' 'relationship' 'over' 'generate' 'once' 'epochs'
#  'weights' 'predicting' 'on' 'of' 'one' 'training' 'previous' 'multiple'
#  'trained' 'by' 'making' 'applications' 'sequence' 'learns' 'the'
#  'context' 'based' 'task' 'autocomplete' 'text' 'dependencies' 'between'
#  'to' 'using' 'at' 'a' 'its' 'given' 'this' 'like' 'chatbots' 'words' 'it'
#  'time' 'hidden' 'in' 'neural' 'recurrent' 'adjusting' 'predict' 'state'
#  'processing' 'during' 'rnn' 'generation' 'data' 'is' 'generation'
#  'retain' 'useful' 'and' 'rnns' 'networks' 'patterns' 'are' 'widely'
#  'remember' 'used' 'can' 'for' 'they' 'next']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ['over' 'generate' 'epochs' 'on' 'weights' 'once' 'relationship'
#  'multiple' 'predicting' 'one' 'training' 'based' 'model' 'previous'
#  'trained' 'making' 'applications' 'sequences' 'context' 'by'
#  'autocomplete' 'of' 'given' 'between' 'sequence' 'to' 'text' 'the' 'a'
#  'at' 'learns' 'it' 'like' 'time' 'using' 'task' 'predict' 'hidden'
#  'chatbots' 'neural' 'its' 'rnn' 'during' 'is' 'recurrent' 'adjusting'
#  'words' 'this' 'state' 'rnns' 'generation' 'dependencies' 'generation'
#  'processing' 'retain' 'useful' 'data' 'in' 'networks' 'are' 'and'
#  'widely' 'patterns' 'used' 'for' 'remember' 'next' 'can' 'word']
# 'neural neural networks networks are widely used for word prediction because'
