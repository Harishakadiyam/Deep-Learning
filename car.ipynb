# %%
import cv2

# %%
cap = cv2.VideoCapture(r'C:\Users\Admin\Downloads\cardetection.mp4')
print(cap.isOpened())
# Out:
# True

# %%
ret, frame = cap.read()
print("Frame captured:", ret)
# Out:
# Frame captured: True

# %%
if frame is None:
    print("⚠️ Frame is empty (None)")
else:
    print("✅ Frame loaded, showing preview...")
    cv2.imshow("Preview", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ✅ Frame loaded, showing preview...
